# %% [markdown]
# # General example of image opening and handling

# %%
import image_viewer_class
import os
# %matplotlib qt

# %%
iv = image_viewer_class.image_viewer('test_images', folder_list = os.listdir('test_images'))
iv.df_files[iv.df_files['folder_found'] == 'Desi']

iv.view_image(43,
                manipulation_kw={
                    'centered' : ('238.5690d', '+04.7276d'),
                    # 'zoom': '0 1 0 d',
                    'stretch': 'log',
                    # 'percentile': (1, 99)
                    'vminmax': (0,10)
                },
                plotting_kw={
                    'cmap': 'gray',
                    'scalebar_arcsec': 1,
                    'scalebar_frame': True,
                    'add_circle' : {
                            'center': ('238.5690d', '+04.7276d'),
                            'size' : '0 0 2 d'}
                }
                )
# Out:
# Current working directory: /Users/oscar/LB/grav_lens
# Image directory defined: /Users/oscar/LB/grav_lens/test_images
# ERROR WITH FILENAME FORMAT CONVENTION EXPECTED:  /Users/oscar/LB/grav_lens/test_images/Q2237+0305/hst_13113_13_wfc3_uvis_f555w_drz.fits
# ERROR WITH FILENAME FORMAT CONVENTION EXPECTED:  /Users/oscar/LB/grav_lens/test_images/Desi/desi_238.fits
# ERROR WITH FILENAME FORMAT CONVENTION EXPECTED:  /Users/oscar/LB/grav_lens/test_images/NIRC2AO/N2.20251111.54503.99_drp.fits
# Total number of images found:  45
# ------
# Viewing image:
# wcs
# Desi/desi_238.fits
# cutout
#     Object:  DESI-238.5690+04.7276   -  Filter:  F140W
