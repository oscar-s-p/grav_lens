# %% [markdown]
# # Photometric analysis

# %%
# %pip install -e '/Users/oscar/LB/imageviewer'
# Out:
# Obtaining file:///Users/oscar/LB/imageviewer
#   Installing build dependencies ... ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import imageviewer
print(imageviewer.__version__)
import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 0.4.4

# %%
data_dir = '/Users/oscar/LB/grav_lens/Proposals'
imageviewer.image_viewer(data_dir, )
# Out:
# Current working directory: /Users/oscar/LB/grav_lens/lib
# Image directory defined: /Users/oscar/LB/grav_lens/Proposals
# WARNING: NO IMAGE FILES FOUND
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 data_dir = '/Users/oscar/LB/grav_lens/Proposals'
# ----> 2 imageviewer.image_viewer(data_dir)
#
# File ~/LB/imageviewer/src/imageviewer/image_viewer_class.py:223, in image_viewer.__init__(self, directory, list_available, folder_list, filters, previous_df, print_error, bad_format, im_type_input)
#     221         self.df_files = pd.concat([df_files, previous_df], ignore_index = True).drop_duplicates(subset = 'filename', keep= 'last')
#     222     else: self.df_files = previous_df
# --> 223 else: self.df_files = df_files
#     224 # if im_type not previously defined in dataset
# ...

# %%
# %pwd
# Out:
# '/Users/oscar/LB/grav_lens/lib'
