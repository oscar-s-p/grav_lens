# %% [markdown]
# # Photometric analysis

# %%
# %pip install -U -e '/Users/oscar/LB/imageviewer'
# Out:
# Obtaining file:///Users/oscar/LB/imageviewer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for imageviewer (pyproject.toml) ... done
#   Created wheel for imageviewer: filename=imageviewer-0.4.5-0.editable-py3-none-any.whl size=4330 sha256=5bf8d7d0033c81d0b71f117ba61bfc623865f01045814e91778255864dba22b3
#   Stored in directory: /private/var/folders/lp/gmwtz0k15l9131lfg2fd97bh0000gn/T/pip-ephem-wheel-cache-6_zc9f3v/wheels/cf/ba/3a/80024520cc37b5667fe141f5b01a7e47b97286124514acadcc
# Successfully built imageviewer
# ...
#   Attempting uninstall: imageviewer
#     Found existing installation: imageviewer 0.4.4
#     Uninstalling imageviewer-0.4.4:
#       Successfully uninstalled imageviewer-0.4.4
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# ...

# %%
import imageviewer
print(imageviewer.__version__)
import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 0.4.5

# %%
data_dir = '/Users/oscar/LB/grav_lens/Proposals'

iv = imageviewer.image_viewer(data_dir, '232', im_type_input='LB', bad_format=True)
# Out:
# Current working directory: /Users/oscar/LB/grav_lens/lib
# Image directory defined: /Users/oscar/LB/grav_lens/Proposals
# WARNING: NO IMAGE FILES FOUND
# Empty DataFrame
# Columns: [im_type]
# Index: []
# Total number of images found:  0

# %%
os.listdir(data_dir+'/232')
# Out:
# ['TTT3_iKon936-1_2025-11-29-03-23-42-224983_ZTF25abnjznp_SDSSr.fits',
#  'TTT3_iKon936-1_2025-11-06-02-33-01-072756_ZTF25abnjznp_SDSSg.fits',
#  'TTT3_iKon936-1_2025-12-26-03-20-17-053445_ZTF25abnjznp_SDSSr.fits',
#  'TTT3_iKon936-1_2025-12-23-02-22-57-973712_ZTF25abnjznp_SDSSr.fits',
#  'TTT3_iKon936-1_2025-12-08-20-02-20-242573_DESI-350.3458-03.5082_SDSSzs.fits',
#  'TTT3_iKon936-1_2025-12-18-19-47-12-554200_DESI-350.3458-03.5082_SDSSi.fits',
#  'TTT3_iKon936-1_2025-11-11-06-22-36-264266_ZTF25abnjznp_SDSSr.fits',
#  'TTT3_iKon936-1_2025-11-08-02-34-30-469459_ZTF25abnjznp_SDSSzs.fits',
#  'TTT3_iKon936-1_2025-11-11-06-27-47-413539_ZTF25abnjznp_SDSSi.fits',
#  'TTT3_iKon936-1_2025-12-08-19-41-38-243559_DESI-350.3458-03.5082_SDSSr.fits',
#  'TTT3_iKon936-1_2025-12-06-19-49-23-870420_DESI-350.3458-03.5082_SDSSg.fits',
#  'TTT3_iKon936-1_2025-11-29-03-34-03-275808_ZTF25abnjznp_SDSSi.fits',
#  'TTT3_iKon936-1_2025-12-26-03-27-13-189922_ZTF25abnjznp_SDSSi.fits',
# ...
