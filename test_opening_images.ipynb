# %% [markdown]
# # Reading FITS images from LB telescopes
# First tests with Astropy

# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from astropy.io import fits

# %%
wd = os.getcwd()
directory = 'test_images'
print('Working directory: '+ wd)
print('Directory containing images: '+ directory)
print('Available images')
dir_img = os.path.join(wd, directory)
list_images = os.listdir(dir_img)
print(list_images)
# Out:
# Working directory: /Users/oscar/LB/grav_lens
# Directory containing images: test_images
# Available images
# ['TST_QHY411-3_2025-10-06-05-25-28-669753_QSO0957+561_SDSSg.fits']

# %%
image_file = list_images[0]
hdu_list = fits.open(os.path.join(dir_img,image_file))
hdu_list.info()
# Out:
# Filename: /Users/oscar/LB/grav_lens/test_images/TST_QHY411-3_2025-10-06-05-25-28-669753_QSO0957+561_SDSSg.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     213   (14200, 10650)   float32

# %%
image_data = hdu_list[0].data
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (10650, 14200)
