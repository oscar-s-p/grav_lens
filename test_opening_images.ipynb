# %% [markdown]
# # Reading FITS images from LB telescopes
# First tests with Astropy

# %%
import os, sys, glob
from pathlib import Path
import datetime as dt
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib qt

from astropy.io import fits
from astropy import units as u
from astropy.wcs import WCS
from astropy.wcs.wcsapi import SlicedLowLevelWCS
from astropy.wcs.utils import skycoord_to_pixel
from astropy.visualization.wcsaxes import add_scalebar
from astropy.visualization import SimpleNorm, simple_norm
from astropy.visualization import make_lupton_rgb
from astropy.coordinates import Angle
from astropy.coordinates import SkyCoord
from astropy.nddata import Cutout2D

# %%
class image_viewer:
    def __init__(self, directory: str = '',
               list_available: bool = False,
               folder_list = False):
        """Class to quickly open FITS images. Searches in given directory.
        
        Attributes
        ---------
        directory : str
            Directory where images are stored. If none given look in current working directory.

        list_available : bool : False
            Wether to print the resulting dataframe of found images or not

        folder_list : optional, list of str
            Extra directories to inspect for images and save their folder path from working directory
        
        Methods
        --------
        return_index()
            Returns the image path and index in the datafile given one or the other.
        
        header_info()
            Method to view general header info.

        view()
            Method to view images.
    """
        self.folder_list = folder_list
        print('Current working directory: ' + os.getcwd())
        if directory=='':
            directory = os.getcwd()
        if directory != os.getcwd():
            self.dir_img = os.path.join(os.getcwd(),directory)
        else: self.dir_img = directory
        print('Image directory defined: ' + self.dir_img)

        # list of images
        files = list(Path(self.dir_img).glob('*.fits'))
        folder_found = ['']*len(files)
        if folder_list!= False:
            for fl in folder_list:
                fi = list(Path(os.path.join(self.dir_img, fl)).glob('*.fits'))
                files=files+fi
                folder_found =folder_found+[fl]*len(fi)

        files_data = []
        
        for k, f in enumerate(files):
            try:
                name = f.name
                path = str(f.resolve())
                try: telescope, camera, date_time, object, filter = name.split('_')
                except: print('ERROR WITH FILENAME FORMAT CONVENTION EXPECTED')
                size_MB = f.stat().st_size / 1e6
                created = pd.to_datetime(f.stat().st_ctime, unit="s")
                files_data.append({"filename": name, "path": path, "telescope": telescope, 'camera': camera,
                                   "object": object, "filter": filter[:-5], "size_MB": size_MB,
                                   "date_time": pd.to_datetime(date_time, format='%Y-%m-%d-%H-%M-%S-%f'),
                                   "folder_found": folder_found[k]})
            except: print('Error with file: %s'%f)
                
        if len(files)==0:
            print('WARNING: NO IMAGE FILES FOUND')
            return
        self.df_files = pd.DataFrame(files_data).sort_values("filename").reset_index(drop=True)

        # print available images if requested
        if list_available:
            print(self.df_files)
        print('Total number of images found: ', len(self.df_files))
    
    def return_index(self, image):
        """
        Returns the image path and index in the datafile given one or the other.

        Parameters
        ----------
        image: int / str
            int - image index in datafile \n
            str - image path
        """
        if type(image)==int:
            image_str = self.df_files.iloc[image].filename
            image_int = image
        else: 
            image_str = image
            try: image_int = self.df_files.index[self.df_files['filename']==image].to_list()[0]
            except:
                print('\n ERROR: FILENAME NOT FOUND')
                return
        if self.folder_list != False:
            # Extract date, but considering that images from the early am are saved in the folder
            # corresponding to the previous day
            # ------- Old techinque, not necessary maybe ------
            # time = self.df_files.iloc[image_int].date_time
            # if time.hour < 12:
            #     time += dt.timedelta(days=-1)
            # folder_name = str(time.date())
            # -----------------------------------------------
            folder_name = self.df_files.iloc[image_int].folder_found
            image_str = os.path.join(folder_name, image_str)
        return image_str, image_int


    def header_info(self, image,
                    interesting_keys = ['INSTRUME', 'OBJECT', 'FILTER', 'INTEGT', 'DATE-OBS',
                                        'RA', 'DEC', 'NAXIS1', 'NAXIS2', 'SCALE', 'FOVX', 'FOVY',
                                        'CCW', 'CRPIX1', 'CRPIX2']
                                        ):
        """Method to view general header info.
        
        Parameters
        ----------
        image : int / str
            int - index of desired file in dataframe \n
            string - path to desired fits file
            
        interesting_keys: list / 'all'
            list - list of strings with header keyword \n
            'all' - will print the whole header
        """
        image_str, image_int = self.return_index(image)
        
        # Extracting data from header
        with fits.open(os.path.join(self.dir_img, image_str)) as hdul:
            heads = hdul[0].header
            hdul.close()
        # printing basic header info
        print('Image: %s'%image_str)
        print('\n   --- HEADER DATA ---')
        try:
            if type(interesting_keys) == str and interesting_keys=='all':
                print(repr(heads))
            else:
                for k in interesting_keys:
                    if heads.comments[k]!='':
                        print(k, ' = ', heads[k], '  ---  ', heads.comments[k])
                    else:
                        print(k, ' = ', heads[k])
        except:
            print('WARNING: WRONG interesting_keys PARAMETER.')
            print('         Try a list with the strings of header keys or just the string \'all\'')


    def view(self, image,
             centered = True, 
             zoom = False,
             stretch = 'linear',
             percentile = None,
             vminmax = (None, None),
             cmap = 'gray',
             scalebar_arcsec = 5
             ):
        """Method to view images.

        Parameters
        ---------
        image : int / string
            int - index of desired file in dataframe \n
            string - path to desired fits file

        centered : True / tuple 
            (x,y) - int for pix coordinates \n
            (RA, DEC) - wcs coordinates. Accepting both strings or angle values

        zoom : False / Value / Tuple 
            int / (int, int) - pixel size in x and y axis \n
            Angle / (Angle, Angle) - angular size in RA and DEC
        
        stretch : str
            Image stretch to enhance detail visualization \n
            ``linear``, ``sqrt``, ``power``, ``log``, ``sinh``, ``asinh``
        
        percentile : int / tuple
            ``int`` - Middle percentile of values to consider for normalization; 
            ``tuple`` - Lower and upper percentile of values to consider for normalization
        
        vminmax : tuple
            Min and max pixel values for normalization. Overrides ``percentile``.
            If set as None, keeps the absolute min or max of image

        cmap : str
            Select the desired colormap for the image

        scalebar_arcsec : int
            Angular size of scalebar in arcsec units
        """
        image_str, image_int = self.return_index(image)
        print('Viewing ', image_str)

        # Extracting data from header
        with fits.open(os.path.join(self.dir_img, image_str)) as hdul:
            data = hdul[0].data.astype(np.float32)
            heads = hdul[0].header
            wcs = WCS(heads)
            hdul.close()
        
        # obtaining central px coordinates
        x_shape = data.shape[1]
        y_shape = data.shape[0]
        if centered == True:
            center_px = (x_shape//2, y_shape//2)
        if type(centered)==tuple:
            if type(centered[0]) == int: # input in px units
                center_px = tuple(centered)
            if type(centered[0]) == str: # input in str to be converted to deg
                center_angle = SkyCoord(centered[0], centered[1], frame = 'icrs')
                center_px = skycoord_to_pixel(center_angle, wcs, origin=0)
        
        # setting zoom
        if zoom == False:
            zoom = (x_shape, y_shape)
        if type(zoom) == str:
            zoom = Angle(zoom)
        if type(zoom)== tuple:
            if type(zoom[0]) == str:
                zoom = (Angle(zoom[0]), Angle(zoom[1]))
        if type(zoom)==tuple:
            zoom = zoom[::-1]
        
        # slicing image
        try:
            cutout = Cutout2D(data, position = center_px, size = zoom, wcs = wcs)
        except:
            print('\n --- \nERROR: the cutout region is outside of the image.')
            return

        # WCS projection
        fig, ax = plt.subplots(subplot_kw=dict(projection=cutout.wcs))

        # norm definition
        if type(percentile) == int or percentile == None:
            percentile_minmax = (None, None)
        if type(percentile) == tuple:
            percentile_minmax = percentile
            percentile = None
        if stretch not in {'linear', 'sqrt', 'power', 'log', 'sinh', 'asinh'}:
            print('ERROR: Stretch should be one of \'linear\', \'sqrt\', \'power\', \'log\', \'sinh\', \'asinh\'')
            plt.close()
            return
        norm = simple_norm(cutout.data, stretch = stretch, 
                           vmin = vminmax[0], vmax = vminmax[1],
                           percent = percentile,
                           min_percent = percentile_minmax[0],
                           max_percent = percentile_minmax[1])
        
        cax = ax.imshow(cutout.data,
                        norm = norm, origin = 'lower',
                        cmap = cmap)
        cbar = plt.colorbar(cax)
        cbar.set_label('ADU', rotation=270, labelpad=15)
        cbar.ax.tick_params(labelsize=10)

        # Scale bar choosing color depending on luminance of cmap
        scalebar_angle = scalebar_arcsec/3600*u.deg
        rgba = plt.get_cmap(cmap)(0.0)
        luminance = 0.299*rgba[0] + 0.587*rgba[1] + 0.114*rgba[2]
        scalebar_color = 'white' if luminance < 0.5 else 'black'
        add_scalebar(ax, scalebar_angle, label="%s arcsec"%str(scalebar_arcsec), color=scalebar_color)
        # Axis and title
        ax.set(xlabel='RA', ylabel='Dec')
        ax.coords.grid(color='gray', alpha=0.5, linestyle='solid')
        title_str = '$\\bf{Object}$: %s - $\\bf{Telescope}$: %s\n$\\bf{Camera}$: %s - $\\bf{Filter}$: %s - $\\bf{Integration}$: %s s\n$\\bf{Date time}$: %s'%(self.df_files.iloc[image_int]['object'],
                                                                                          self.df_files.iloc[image_int]['telescope'],
                                                                                          self.df_files.iloc[image_int]['camera'],
                                                                                          self.df_files.iloc[image_int]['filter'],
                                                                                          heads['INTEGT'],
                                                                                          self.df_files.iloc[image_int]['date_time'])
        ax.set_title(title_str)
        ax.minorticks_on()
        plt.tight_layout()
        plt.show()
    

    def read_data(self, image):
        """Method to view images."""
        image_str, image_int = self.return_index(image)
        print('Viewing ', image_str)

        # Extracting data from header
        with fits.open(os.path.join(self.dir_img, image_str)) as hdul:
            data = hdul[0].data.astype(np.float32)
            hdul.close()
        return data

# %%
iv = image_viewer('test_images', list_available=False, folder_list=['2025-11-02'])
# iv.df_files
# iv.header_info(1, interesting_keys='all')
# iv.view(4) #span_x=1000, span_y=1000)
iv.view(4, 
        centered = True,#('22h 40m 30.3s', '+3° 21′ 31″'),
        # zoom = ('0 1 d', '0:1 d'),
        stretch = 'sinh',
        percentile = (1,99),
        # vminmax = (2e4, None),
        cmap = 'gray',
        scalebar_arcsec= 5)
# Out:
# Current working directory: /Users/oscar/LB/grav_lens
# Image directory defined: /Users/oscar/LB/grav_lens/test_images
# Total number of images found:  6
# Viewing  2025-11-02/TTT3_iKon936-1_2025-11-02-20-01-44-116500_EinsteinCross_SDSSr.fits

# %%
iv.header_info(4, interesting_keys='all')
# for k in range(5):
#     iv.header_info(k, interesting_keys=['CCW'])
#iv.view(1) #span_x=5000, span_y=5000)
# Out:
# Image: 2025-11-02/TTT3_iKon936-1_2025-11-02-20-01-44-116500_EinsteinCross_SDSSr.fits
#
#    --- HEADER DATA ---
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2048
# NAXIS2  =                 2048
# IMAGETYP= 'SCIENCE '           / Type of image
# COMMENT ***************************
# COMMENT          TELESCOPE
# COMMENT ***************************
# TELESCOP= 'TTT3    '           / Telescope name
# SITENAME= 'Teide Observatory (IAC)' / Telescope site name
# SITECODE= 'Y68     '           / Telescope IAU Code
# SITELAT =          28.29893272 / [deg] Telescope latitude
# SITELONG=         -16.50923428 / [deg] Telescope longitude
# SITEELEV=               2360.0 / [m] Telescope elevation
# DIAMETER=               2000.0 / [mm] Telescope diameter
# FOCAL   =                  6.0 / Telescope focal ratio
# FOCALEN =              12000.0 / [mm] Telescope focal length
# MOUNT   = 'AltAz   '           / Mount type
# TRACK   =                    1 / Sidereal tracking, 0=no, 1=yes
# POINTRA =    22.67509444444445
# POINTDEC=                3.358
# COMMENT ***************************
# COMMENT          INSTRUMENT
# COMMENT ***************************
# INSTRUME= 'iKon936-TTT3'
# CAMERA  = 'iKon936-1'
# INMODEL = 'iKon936 '
# INSERIAL=                27305
# INFIRMW = '20.12   '
# INSDK   = '2.104   '
# PXSIZE  =                 13.5
# HSSPEED =                  1.0
# VSSPEED =            38.549999
# PREAMPGA=                  4.0
# RDMODE  = 'Image   '
# XBINNING=                    1
# YBINNING=                    1
# SHMODE  = 'Mechanical shutter' / Electronic shutter mode
# DRMODE  =  / Dynamic range mode
# COMODE  =  / Color mode
# RDNOISE =                  6.2 / [e] Readout noise
# OFFSET  =  / [ADU] Pedestal level
# SATLEVEL=                65536 / [ADU] Saturation level
# GAIN    =                  1.0 / [e/ADU] Gain
# DC      =                0.006 / [e/s] Nominal dark current
# PARITY  = 'pos     '           / Image parity
# EFFECTSX=                    0 / Effective region origin in X axis
# EFFECTNX=                 2048 / Effective region lines in X axis
# EFFECTSY=                    0 / Effective region origin in Y axis
# EFFECTNY=                 2048 / Effective region lines in Y axis
# STATSX  =                  500 / Stats region origin in X axis
# STATNX  =                 1000 / Stats region lines in X axis
# STATSY  =                  500 / Stats region origin in Y axis
# STATNY  =                 1000 / Stats region lines in Y axis
# FOCUS   =                 3192 / [um] Focuser position
# WINDOWSX=                    0
# WINDOWNX=                 2048
# WINDOWSY=                    0
# WINDOWNY=                 2048
# FILTER  = 'SDSSr   '
# COMMENT ***************************
# COMMENT       EXPOSITION DATA
# COMMENT ***************************
# DATE-OBS= '2025-11-02T20:01:44.116500'
# JD-OBS  =    2460982.334538385 / Julian date
# MJD-OBS =    60981.83453838542 / Modified julian date
# PCDATE  = '2025-11-02T20:01:44.116500'
# EXPTIME =              180.001
# INTEMP  =              -69.512
# OBJECT  = 'EinsteinCross'
# UT1     = '2025-11-02T20:01:44.116500' / [UTC] Datetime of sub-frame 1
# PCDAT1  = '2025-11-02T20:01:44.116500' / PC [UTC] Datetime of sub-frame 1
# EXPT1   =              180.001 / [s] Exposure time of sub-frame 1
# TEMP1   =              -69.512 / [C] Instrument temperature of sub-frame 1
# COOLERST= 'DRV_TEMP_STABILIZED'
# UTOBS   = '2025-11-02T20:03:14.117000' / [UTC] Mean datetime of observation
# INTEGT  =                180.0 / [s] Sum of all exposition times
# TOTIMA  =                    1 / Number of captures for this image
# ORID    =                66528
# OBID    =              4069112
# OBLINEID=              4513290
# COMMENT ***************************
# COMMENT         PRE-REDUCTION
# COMMENT ***************************
# BIASCORR= 'bias    '           / Bias correction method
# BIASMEAN=              258.362 / [ADU] MasterBias mean
# BIASSTD =                6.254 / [ADU] MasterBias standard deviation
# BIASN   =                   21 / Number of stacked frames in MasterBias
# BIASTEMP=              -69.512 / [C] Instrument temperature of MasterBias
# BIASDATE= '2025-10-03T01:16:17.856772' / [UTC] Date of capture of MasterBias
# FLATMEAN=            12957.908 / [ADU] Mean of the MasterFlat frame
# FLATSTD =              177.686 / [ADU] Standard deviation in flat stacking
# FLATN   =                   11 / Number of staked frames in MasterFlat
# FLATTEMP=              -68.863 / [C] Instrument temperature of MasterFlat
# FLATDATE= '2025-11-02T18:45:10.292529' / [UTC] Date of capture of MasterFlat
# DATE    = '2025-11-02T20:05:08' / [UTC] Date of file creation
# COMMENT ***************************
# COMMENT         WEATHER DATA
# COMMENT ***************************
# HUMIDITY=                 28.6 / [%] Relative humidity
# PRESSURE=                774.4 / [mbar] Local pressure
# AMBTEMP =                 14.6 / [C] Ambient temperature
# CLOUD   =                  0.0 / Cloud presence, 0 = Clear, 1 = Cloudy
# WINDDIR =                199.0 / [deg] Wind direction
# WINDVEL =                 1.97 / [m/s] Wind speed
# DUSTPLA =                0.004 / [PLA/m3] Dust, in Polystyrol-Latex-Aerosols
# DUSTPM1 =                 0.34 / [ug/m3] Particle matter density <1 micron
# DUSTPM10=                 1.13 / [ug/m3] Particle matter density <10 micron
# DUSTPM25=   0.8100000000000001 / [ug/m3] Particle matter density <2.5 micron
# DEWPOINT=                 -2.4 / [C] Dew point
# TESSMAG =                17.83 / [mag/arcsec2] TESS-W cenital sky brightness
# SKYIRTEM=               -17.15 / [C] IR cenital sky temperature
# COMMENT ***************************
# COMMENT        ASTROMETRY
# COMMENT ***************************
# RA      =    340.1265440130891 / [deg] Central right ascension
# DEC     =    3.357754897693203 / [deg] Central declination
# RAHMS   = '22:40:30.370563'    / [hh:mm:ss] Central Right ascension
# DECDMS  = '03:21:27.917632'    / [dd:mm:ss] Central declination
# FOVX    =                 7.85 / [arcmin] Field of view in x axis
# FOVY    =                 7.85 / [arcmin] Field of view in y axis
# SCALE   =                 0.23 / [arcsec/px] Calculated plate scale
# CCW     =                  0.5 / [deg] Field rotation counterclockwise
# AZ      =           148.871443 / [deg] Azimut
# ALT     =            61.755893 / [deg] Altitude
# ZD      =            28.244107 / [deg] Zenital distance, in degrees
# AIRMASS =             1.135152 / Airmass
# LONGAL  =    71.79859999999999 / [deg] Galactic longitude
# LATGAL  =           -46.109469 / [deg] Galactic latitude
# LONECL  =           342.942557 / [deg] Baricentric mean ecliptic longitude
# LATECL  =            10.878495 / [deg] Baricentric mean ecliptic latitude
# MOONALT =                46.59 / [deg] Moon altitude
# MOONAZ  =               121.01 / [deg] Moon azimut
# MOONILUM=    89.42100000000001 / [%] Moon illumination
# MOONDIST=                21.96 / [deg] Distance to Moon
# SUNALT  =               -22.71 / [deg] Sun altitude
# SUNAZ   =               264.62 / [deg] Sun azimut
# WCSAXES =                    2 / Number of coordinate axes
# EQUINOX =               2000.0 / Equatorial coordinates definition (yr)
# LONPOLE =                180.0 / Native longitude of celestial pole (deg)
# LATPOLE =                  0.0 / Native latitude of celestial pole (deg)
# CRVAL1  =    340.1352995554195 / RA of reference point
# CRVAL2  =    3.315945381610815 / DEC of reference point
# CRPIX1  =    881.5168612703169 / X reference pixel
# CRPIX2  =    371.5235439700527 / Y reference pixel
# CUNIT1  = 'deg     '           / X pixel scale units
# CUNIT2  = 'deg     '           / Y pixel scale units
# CD1_1   = -6.3941033248090E-05 / Transformation matrix
# CD1_2   = 5.67078184498402E-07 / Transformation matrix
# CD2_1   = 5.81780695410914E-07 / Transformation matrix
# CD2_2   = 6.39512250493222E-05 / Transformation matrix
# CTYPE1  = 'RA---TAN-SIP'       / TAN (gnomonic) projection + SIP distortions
# CTYPE2  = 'DEC--TAN-SIP'       / TAN (gnomonic) projection + SIP distortions
# A_ORDER =                    1 / Polynomial order, axis 1
# A_0_0   =                  0.0 / Polynomial coefficient, axis 1
# A_0_1   =                  0.0 / Polynomial coefficient, axis 1
# A_1_0   =                  0.0 / Polynomial coefficient, axis 1
# B_ORDER =                    1 / Polynomial order, axis 2
# B_0_0   =                  0.0 / Polynomial coefficient, axis 2
# B_0_1   =                  0.0 / Polynomial coefficient, axis 2
# B_1_0   =                  0.0 / Polynomial coefficient, axis 2
# AP_ORDER=                    1 / Inv polynomial order, axis 1
# AP_0_0  =                 -0.0 / Inv polynomial coefficient, axis 1
# AP_0_1  =                  0.0 / Inv polynomial coefficient, axis 1
# AP_1_0  =                 -0.0 / Inv polynomial coefficient, axis 1
# BP_ORDER=                    1 / Inv polynomial order, axis 2
# BP_0_0  =                 -0.0 / Inv polynomial coefficient, axis 2
# BP_0_1  =                  0.0 / Inv polynomial coefficient, axis 2
# BP_1_0  =                 -0.0 / Inv polynomial coefficient, axis 2
# COMMENT ***************************
# COMMENT        PHOTOMETRY
# COMMENT ***************************
# FLUXSKY =         18034.189782 / [ADU/px] Median sky flux per pixel
# FWHM    =    4.229829167619682 / [px] FWHM in the center of the image
# RAD10   =                    4 / [px] Aperture radius for stars with SNR = 10
# CORR10  =                0.677 / Aperture correction factor for SNR = 10
# RAD100  =                   18 / [px] Aperture radius for stars with SNR = 100
# CORR100 =                0.988 / Aperture correction factor for SNR = 100
# RAD250  =                   18
# CORR250 =                0.988
# RAD1000 =                   18 / [px] Aperture radius for stars with SNR = 1000
# CORR1000=                0.988 / Aperture correction factor for SNR = 1000
# CATALOG = 'II/349/ps1'         / Photometric catalog used in calibration
# CATBAND = 'r       '           / Catalog passband
# ZP      =               25.143 / [ADU/s] Zeropoint
# EZP     =               0.0122 / [ADU/s] Zeropoint uncertainty (1-sigma)
# CATNSTAR=                    9 / Number of stars used in ZP
# ZPMINMAG=                14.91 / [mag] Brightest star magnitude for ZP
# ZPMAXMAG=                 18.3 / [mag] Faintest star magnitude for ZP
# BVMIN   =                 0.05 / [B-V] Minimum color for ZP stars
# BVMAX   =                 1.25 / [B-V] Maximum color for ZP stars
# MAGLIM  =                22.18 / [mag] 3-sigma limiting magnitude
# RAPREC  =               -0.018 / [arcsec] RA precision of detected sources
# DECPREC =                0.018 / [arcsec] DEC precision of detected sources
# RADISP  =                0.307 / [arcsec] RA dispersion of detected sources
# DECDISP =                 0.23 / [arcsec] DEC dispersion of detected sources
# OBJECSNR=                58.16 / Target signal-to-noise ratio
# DATEPROC= '2025-11-02T20:08:59.536208' / [UTC] Date when the file was processed

# %%
iv.header_info(5, interesting_keys='all')
# Out:
# Image: 2025-11-02/TTT3_iKon936-1_2025-11-02-20-04-48-990118_EinsteinCross_SDSSr.fits
#
#    --- HEADER DATA ---
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2048
# NAXIS2  =                 2048
# IMAGETYP= 'SCIENCE '           / Type of image
# COMMENT ***************************
# COMMENT          TELESCOPE
# COMMENT ***************************
# TELESCOP= 'TTT3    '           / Telescope name
# SITENAME= 'Teide Observatory (IAC)' / Telescope site name
# SITECODE= 'Y68     '           / Telescope IAU Code
# SITELAT =          28.29893272 / [deg] Telescope latitude
# SITELONG=         -16.50923428 / [deg] Telescope longitude
# SITEELEV=               2360.0 / [m] Telescope elevation
# DIAMETER=               2000.0 / [mm] Telescope diameter
# FOCAL   =                  6.0 / Telescope focal ratio
# FOCALEN =              12000.0 / [mm] Telescope focal length
# MOUNT   = 'AltAz   '           / Mount type
# TRACK   =                    1 / Sidereal tracking, 0=no, 1=yes
# POINTRA =    22.67509444444445
# POINTDEC=                3.358
# COMMENT ***************************
# COMMENT          INSTRUMENT
# COMMENT ***************************
# INSTRUME= 'iKon936-TTT3'
# CAMERA  = 'iKon936-1'
# INMODEL = 'iKon936 '
# INSERIAL=                27305
# INFIRMW = '20.12   '
# INSDK   = '2.104   '
# PXSIZE  =                 13.5
# HSSPEED =                  1.0
# VSSPEED =            38.549999
# PREAMPGA=                  4.0
# RDMODE  = 'Image   '
# XBINNING=                    1
# YBINNING=                    1
# SHMODE  = 'Mechanical shutter' / Electronic shutter mode
# DRMODE  =  / Dynamic range mode
# COMODE  =  / Color mode
# RDNOISE =                  6.2 / [e] Readout noise
# OFFSET  =  / [ADU] Pedestal level
# SATLEVEL=                65536 / [ADU] Saturation level
# GAIN    =                  1.0 / [e/ADU] Gain
# DC      =                0.006 / [e/s] Nominal dark current
# PARITY  = 'pos     '           / Image parity
# EFFECTSX=                    0 / Effective region origin in X axis
# EFFECTNX=                 2048 / Effective region lines in X axis
# EFFECTSY=                    0 / Effective region origin in Y axis
# EFFECTNY=                 2048 / Effective region lines in Y axis
# STATSX  =                  500 / Stats region origin in X axis
# STATNX  =                 1000 / Stats region lines in X axis
# STATSY  =                  500 / Stats region origin in Y axis
# STATNY  =                 1000 / Stats region lines in Y axis
# FOCUS   =                 3192 / [um] Focuser position
# WINDOWSX=                    0
# WINDOWNX=                 2048
# WINDOWSY=                    0
# WINDOWNY=                 2048
# FILTER  = 'SDSSr   '
# COMMENT ***************************
# COMMENT       EXPOSITION DATA
# COMMENT ***************************
# DATE-OBS= '2025-11-02T20:04:48.990118'
# JD-OBS  =    2460982.336678126 / Julian date
# MJD-OBS =    60981.83667812637 / Modified julian date
# PCDATE  = '2025-11-02T20:04:48.990118'
# EXPTIME =              180.001
# INTEMP  =              -69.512
# OBJECT  = 'EinsteinCross'
# UT1     = '2025-11-02T20:04:48.990118' / [UTC] Datetime of sub-frame 1
# PCDAT1  = '2025-11-02T20:04:48.990118' / PC [UTC] Datetime of sub-frame 1
# EXPT1   =              180.001 / [s] Exposure time of sub-frame 1
# TEMP1   =              -69.512 / [C] Instrument temperature of sub-frame 1
# COOLERST= 'DRV_TEMP_STABILIZED'
# UTOBS   = '2025-11-02T20:06:18.990618' / [UTC] Mean datetime of observation
# INTEGT  =                180.0 / [s] Sum of all exposition times
# TOTIMA  =                    1 / Number of captures for this image
# ORID    =                66528
# OBID    =              4069112
# OBLINEID=              4513291
# COMMENT ***************************
# COMMENT         PRE-REDUCTION
# COMMENT ***************************
# BIASCORR= 'bias    '           / Bias correction method
# BIASMEAN=              258.362 / [ADU] MasterBias mean
# BIASSTD =                6.254 / [ADU] MasterBias standard deviation
# BIASN   =                   21 / Number of stacked frames in MasterBias
# BIASTEMP=              -69.512 / [C] Instrument temperature of MasterBias
# BIASDATE= '2025-10-03T01:16:17.856772' / [UTC] Date of capture of MasterBias
# FLATMEAN=            12957.908 / [ADU] Mean of the MasterFlat frame
# FLATSTD =              177.686 / [ADU] Standard deviation in flat stacking
# FLATN   =                   11 / Number of staked frames in MasterFlat
# FLATTEMP=              -68.863 / [C] Instrument temperature of MasterFlat
# FLATDATE= '2025-11-02T18:45:10.292529' / [UTC] Date of capture of MasterFlat
# DATE    = '2025-11-02T20:08:15' / [UTC] Date of file creation
# COMMENT ***************************
# COMMENT         WEATHER DATA
# COMMENT ***************************
# HUMIDITY=                 28.6 / [%] Relative humidity
# PRESSURE=                774.5 / [mbar] Local pressure
# AMBTEMP =                 14.6 / [C] Ambient temperature
# CLOUD   =                  0.0 / Cloud presence, 0 = Clear, 1 = Cloudy
# WINDDIR =                197.0 / [deg] Wind direction
# WINDVEL =                 1.97 / [m/s] Wind speed
# DUSTPLA =                0.004 / [PLA/m3] Dust, in Polystyrol-Latex-Aerosols
# DUSTPM1 =                 0.33 / [ug/m3] Particle matter density <1 micron
# DUSTPM10=                 0.46 / [ug/m3] Particle matter density <10 micron
# DUSTPM25=                0.455 / [ug/m3] Particle matter density <2.5 micron
# DEWPOINT=                 -2.4 / [C] Dew point
# TESSMAG =                17.86 / [mag/arcsec2] TESS-W cenital sky brightness
# SKYIRTEM=               -18.06 / [C] IR cenital sky temperature
# COMMENT ***************************
# COMMENT        ASTROMETRY
# COMMENT ***************************
# RA      =    340.1266431730724 / [deg] Central right ascension
# DEC     =    3.357755559176836 / [deg] Central declination
# RAHMS   = '22:40:30.394362'    / [hh:mm:ss] Central Right ascension
# DECDMS  = '03:21:27.920013'    / [dd:mm:ss] Central declination
# FOVX    =                 7.85 / [arcmin] Field of view in x axis
# FOVY    =                 7.85 / [arcmin] Field of view in y axis
# SCALE   =                 0.23 / [arcsec/px] Calculated plate scale
# CCW     =                  0.5 / [deg] Field rotation counterclockwise
# AZ      =           150.337405 / [deg] Azimut
# ALT     =            62.099976 / [deg] Altitude
# ZD      =            27.900024 / [deg] Zenital distance, in degrees
# AIRMASS =             1.131522 / Airmass
# LONGAL  =            71.798703 / [deg] Galactic longitude
# LATGAL  =           -46.109538 / [deg] Galactic latitude
# LONECL  =           342.942651 / [deg] Baricentric mean ecliptic longitude
# LATECL  =            10.878458 / [deg] Baricentric mean ecliptic latitude
# MOONALT =                47.17 / [deg] Moon altitude
# MOONAZ  =               121.72 / [deg] Moon azimut
# MOONILUM=               89.437 / [%] Moon illumination
# MOONDIST=                21.98 / [deg] Distance to Moon
# SUNALT  =               -23.39 / [deg] Sun altitude
# SUNAZ   =               264.96 / [deg] Sun azimut
# WCSAXES =                    2 / Number of coordinate axes
# EQUINOX =               2000.0 / Equatorial coordinates definition (yr)
# LONPOLE =                180.0 / Native longitude of celestial pole (deg)
# LATPOLE =                  0.0 / Native latitude of celestial pole (deg)
# CRVAL1  =    340.1479997524368 / RA of reference point
# CRVAL2  =    3.353123834773394 / DEC of reference point
# CRPIX1  =    690.0270297764222 / X reference pixel
# CRPIX2  =    954.7118192844508 / Y reference pixel
# CUNIT1  = 'deg     '           / X pixel scale units
# CUNIT2  = 'deg     '           / Y pixel scale units
# CD1_1   = -6.3956041681758E-05 / Transformation matrix
# CD1_2   = 5.72564911657446E-07 / Transformation matrix
# CD2_1   = 6.01451624354911E-07 / Transformation matrix
# CD2_2   = 6.39515788549203E-05 / Transformation matrix
# CTYPE1  = 'RA---TAN-SIP'       / TAN (gnomonic) projection + SIP distortions
# CTYPE2  = 'DEC--TAN-SIP'       / TAN (gnomonic) projection + SIP distortions
# A_ORDER =                    1 / Polynomial order, axis 1
# A_0_0   =                  0.0 / Polynomial coefficient, axis 1
# A_0_1   =                  0.0 / Polynomial coefficient, axis 1
# A_1_0   =                  0.0 / Polynomial coefficient, axis 1
# B_ORDER =                    1 / Polynomial order, axis 2
# B_0_0   =                  0.0 / Polynomial coefficient, axis 2
# B_0_1   =                  0.0 / Polynomial coefficient, axis 2
# B_1_0   =                  0.0 / Polynomial coefficient, axis 2
# AP_ORDER=                    1 / Inv polynomial order, axis 1
# AP_0_0  =                 -0.0 / Inv polynomial coefficient, axis 1
# AP_0_1  =                  0.0 / Inv polynomial coefficient, axis 1
# AP_1_0  =                 -0.0 / Inv polynomial coefficient, axis 1
# BP_ORDER=                    1 / Inv polynomial order, axis 2
# BP_0_0  =                 -0.0 / Inv polynomial coefficient, axis 2
# BP_0_1  =                  0.0 / Inv polynomial coefficient, axis 2
# BP_1_0  =                 -0.0 / Inv polynomial coefficient, axis 2
# COMMENT ***************************
# COMMENT        PHOTOMETRY
# COMMENT ***************************
# FLUXSKY =         17944.634154 / [ADU/px] Median sky flux per pixel
# FWHM    =    4.160290105225705 / [px] FWHM in the center of the image
# RAD10   =                    4 / [px] Aperture radius for stars with SNR = 10
# CORR10  =                0.702 / Aperture correction factor for SNR = 10
# RAD100  =                   19 / [px] Aperture radius for stars with SNR = 100
# CORR100 =                0.988 / Aperture correction factor for SNR = 100
# RAD250  =                   12
# CORR250 =                0.952
# RAD1000 =                   12 / [px] Aperture radius for stars with SNR = 1000
# CORR1000=                0.952 / Aperture correction factor for SNR = 1000
# CATALOG = 'II/349/ps1'         / Photometric catalog used in calibration
# CATBAND = 'r       '           / Catalog passband
# ZP      =                25.15 / [ADU/s] Zeropoint
# EZP     =               0.0153 / [ADU/s] Zeropoint uncertainty (1-sigma)
# CATNSTAR=                   10 / Number of stars used in ZP
# ZPMINMAG=                14.91 / [mag] Brightest star magnitude for ZP
# ZPMAXMAG=                19.17 / [mag] Faintest star magnitude for ZP
# BVMIN   =                 0.05 / [B-V] Minimum color for ZP stars
# BVMAX   =                 1.25 / [B-V] Maximum color for ZP stars
# MAGLIM  =                22.18 / [mag] 3-sigma limiting magnitude
# RAPREC  =                0.004 / [arcsec] RA precision of detected sources
# DECPREC =                0.029 / [arcsec] DEC precision of detected sources
# RADISP  =                0.229 / [arcsec] RA dispersion of detected sources
# DECDISP =                0.205 / [arcsec] DEC dispersion of detected sources
# OBJECSNR=               141.81 / Target signal-to-noise ratio
# DATEPROC= '2025-11-03T12:32:47.464143' / [UTC] Date when the file was processed

# %%
a = np.sqrt(6.3956041681758E-05**2 + 5.72564911657446E-07**2)
b = np.sqrt(6.01451624354911E-07**2 + 6.39515788549203E-05**2)

print(a*3600, b*3600)
# Out:
# 0.23025097644173348 0.2302358654074819

# %%
im_i = 4
hdulist = fits.open(os.path.join(iv.dir_img,iv.return_index(im_i)[0]))
hdu = hdulist[0]
wcs = WCS(hdu.header)

fig, ax = plt.subplots(subplot_kw=dict(projection=wcs))
# Create an ImageNormalize object
snorm = SimpleNorm('sinh', vmin =1.8e4, vmax=3e4)#percent = 98)
axim = snorm.imshow(hdu.data, ax=ax, origin='lower')
fig.colorbar(axim)
#ax.imshow(hdu.data, origin='lower', cmap='viridis', norm = 'log')
ax.set_title('WCS plot of\n%s'%iv.return_index(im_i)[0])
ax.coords.grid(color='white', alpha=0.5, linestyle='solid')

# Add a scale bar
scalebar_angle = 5/3600*u.deg
add_scalebar(ax, scalebar_angle, label="5 arcsec", color="white")
ax.set(xlabel='RA', ylabel='Dec')
ax.scatter(340.1265440130891*u.deg, 3.357754897693203*u.deg, transform = ax.get_transform('icrs'), s=300)
ax.scatter(Angle('22 40 30.234 hours').to(u.deg), Angle('+03:21:30.63 degrees'), transform = ax.get_transform('icrs'), s=200, color = 'red')
plt.show()
# Out:
# qt.qpa.backingstore: Back buffer dpr of 2 doesn't match <NSViewBackingLayer: 0x8cb1f3250> contents scale of 1 - updating layer to match.
# Traceback (most recent call last):
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_qt.py", line 523, in _draw_idle
#     self.draw()
#     ~~~~~~~~~^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py", line 382, in draw
#     self.figure.draw(self.renderer)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 94, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/figure.py", line 3257, in draw
#     mimage._draw_list_compositing_images(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         renderer, self, artists, self.suppressComposite)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/image.py", line 134, in _draw_list_compositing_images
#     a.draw(renderer)
#     ~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 38, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/astropy/visualization/wcsaxes/core.py", line 591, in draw
#     super().draw(renderer)
#     ~~~~~~~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py", line 3190, in draw
#     self._update_title_position(renderer)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py", line 3144, in _update_title_position
#     if title.get_window_extent(renderer).ymin < top:
#        ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 969, in get_window_extent
#     bbox, info, descent = self._get_layout(self._renderer)
#                           ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 382, in _get_layout
#     w, h, d = _get_text_metrics_with_cache(
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         renderer, clean_line, self._fontproperties,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         ismath=ismath, dpi=self.get_figure(root=True).dpi)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 69, in _get_text_metrics_with_cache
#     return _get_text_metrics_with_cache_impl(
#         weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 77, in _get_text_metrics_with_cache_impl
#     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py", line 215, in get_text_width_height_descent
#     self.mathtext_parser.parse(s, self.dpi, prop)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/mathtext.py", line 86, in parse
#     return self._parse_cached(s, dpi, prop, antialiased, load_glyph_flags)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/mathtext.py", line 100, in _parse_cached
#     box = self._parser.parse(s, fontset, fontsize, dpi)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/_mathtext.py", line 2173, in parse
#     raise ValueError("\n" + ParseException.explain(err, 0)) from None
# ValueError:
# \textbf{Object}
#      ^
# ParseSyntaxException: Expected \text, found 'bf'  (at char 5), (line:1, col:6)
# Traceback (most recent call last):
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_qt.py", line 523, in _draw_idle
#     self.draw()
#     ~~~~~~~~~^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py", line 382, in draw
#     self.figure.draw(self.renderer)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 94, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/figure.py", line 3257, in draw
#     mimage._draw_list_compositing_images(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         renderer, self, artists, self.suppressComposite)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/image.py", line 134, in _draw_list_compositing_images
#     a.draw(renderer)
#     ~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 38, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/astropy/visualization/wcsaxes/core.py", line 591, in draw
#     super().draw(renderer)
#     ~~~~~~~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py", line 3190, in draw
#     self._update_title_position(renderer)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py", line 3144, in _update_title_position
#     if title.get_window_extent(renderer).ymin < top:
#        ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 969, in get_window_extent
#     bbox, info, descent = self._get_layout(self._renderer)
#                           ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 382, in _get_layout
#     w, h, d = _get_text_metrics_with_cache(
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         renderer, clean_line, self._fontproperties,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         ismath=ismath, dpi=self.get_figure(root=True).dpi)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 69, in _get_text_metrics_with_cache
#     return _get_text_metrics_with_cache_impl(
#         weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/text.py", line 77, in _get_text_metrics_with_cache_impl
#     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py", line 215, in get_text_width_height_descent
#     self.mathtext_parser.parse(s, self.dpi, prop)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/mathtext.py", line 86, in parse
#     return self._parse_cached(s, dpi, prop, antialiased, load_glyph_flags)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/mathtext.py", line 100, in _parse_cached
#     box = self._parser.parse(s, fontset, fontsize, dpi)
#   File "/Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/_mathtext.py", line 2173, in parse
#     raise ValueError("\n" + ParseException.explain(err, 0)) from None
# ValueError:
# f{Object}$: EinsteinCross - Telescope: TTT3
# ^
# ParseException: Expected end of text, found '$'  (at char 0), (line:1, col:1)
# /Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/astropy/visualization/stretch.py:600: RuntimeWarning: divide by zero encountered in log
#   np.log(values, out=values)

# %%
Angle('22 40 30.234 hours').to(u.deg)
# Out:
# <Angle 340.125975 deg>

# %%
for im_i, filter in zip([3,4],['g','r']):
    hdulist = fits.open(os.path.join(iv.dir_img,iv.return_index(im_i)[0]))
    hdu = hdulist[0]
    globals()[filter] = hdu.data
    hdulist.close()
def normalize(data):
    data_min, data_max = np.percentile(data, (1, 99))
    data = np.clip(data, data_min, data_max)
    return (data - data_min) / (data_max - data_min)
g_n = normalize(g)
r_n = normalize(r)
i = np.zeros_like(g)
rgb_default = make_lupton_rgb(g_n, r_n, i)#, filename="ngc6976-default.jpeg")
fig, ax = plt.subplots()
ax.imshow(rgb_default, origin='lower')
fig.colorbar(ax)
# Out:
# /Users/oscar/LB/grav_lens/.venv/lib/python3.13/site-packages/astropy/visualization/lupton_rgb.py:645: RuntimeWarning: invalid value encountered in divide
#   fInorm = np.where(Int <= 0, 0, np.true_divide(fI, Int))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 16
#      14 fig, ax = plt.subplots()
#      15 ax.imshow(rgb_default, origin='lower')
# ---> 16 fig.colorbar(ax)
#
# File ~/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/figure.py:1308, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1300         _api.warn_external(
#    1301                 f'Adding colorbar to a different Figure '
#    1302                 f'{repr(mappable_host_fig)} than '
#    1303                 f'{repr(self._root_figure)} which '
#    1304                 f'fig.colorbar is called on.')
#    1306 NON_COLORBAR_KEYS = [  # remove kws that cannot be passed to Colorbar
#    1307     'fraction', 'pad', 'shrink', 'aspect', 'anchor', 'panchor']
# -> 1308 cb = cbar.Colorbar(cax, mappable, **{
#    1309     k: v for k, v in kwargs.items() if k not in NON_COLORBAR_KEYS})
#    1310 cax.get_figure(root=False).stale = True
#    1311 return cb
#
# File ~/LB/grav_lens/.venv/lib/python3.13/site-packages/matplotlib/colorbar.py:294, in Colorbar.__init__(self, ax, mappable, alpha, location, extend, extendfrac, extendrect, ticks, format, values, boundaries, spacing, drawedges, label, cmap, norm, orientation, ticklocation)
#     291     mappable = cm.ScalarMappable(norm=norm, cmap=cmap)
#     293 self.mappable = mappable
# --> 294 cmap = mappable.cmap
#     295 norm = mappable.norm
#     297 filled = True
#
# AttributeError: 'Axes' object has no attribute 'cmap'

# %%
iv.header_info(1, interesting_keys='all')
#iv.view(2, span_x = 3000, span_y = 3000, center_xy = [7000, 5000]) #span=(400,400), print_info = True)
# Out:
# Image: TTT1_QHY411-1_2025-01-08-23-13-10-194024_SDSSJ0819+5356_SDSSr.fits
#
#    --- HEADER DATA ---
# SIMPLE  =  True   ---   conforms to FITS standard
# BITPIX  =  -32   ---   array data type
# NAXIS  =  2   ---   number of array dimensions
# NAXIS1  =  14200   ---
# NAXIS2  =  10650   ---
# GPSDAT  =  2025-01-08T23:13:10.194024   ---
# GPSLAT  =  28.2987605   ---
# GPSLON  =  -16.50956333333333   ---
# SEQNUM  =  2   ---
# IMAGETYP  =  SCIENCE   ---   Type of image
# TELESCOP  =  TTT1   ---   Telescope name
# SITENAME  =  Teide Observatory (IAC)   ---   Telescope site name
# SITECODE  =  Y65   ---   Telescope IAU Code
# SITELAT  =  28.29871121   ---   [deg] Telescope latitude
# SITELONG  =  -16.50956893   ---   [deg] Telescope longitude
# SITEELEV  =  2359.12   ---   [m] Telescope elevation
# DIAMETER  =  800.0   ---   [mm] Telescope diameter
# FOCAL  =  6.85   ---   Telescope focal ratio
# FOCALEN  =  5480.0   ---   [mm] Telescope focal length
# MOUNT  =  AltAz   ---   Mount type
# TRACK  =  1   ---   Sidereal tracking, 0=no, 1=yes
# POINTRA  =  8.333272222222222   ---
# POINTDEC  =  53.94018   ---
# INSTRUME  =  QHY411-TTT1   ---
# CAMERA  =  QHY411-1   ---
# INMODEL  =  QHY411MERIS   ---
# INSERIAL  =  2566a14f9ee62fe1a   ---
# INFIRMW  =  2015_15_0   ---
# INSDK  =  23-11-17.12   ---
# OFFSET  =  10.0   ---
# GAMODE  =  20.0   ---
# PXSIZE  =  3.76   ---
# RDMODE  =  Full Frame Read Mode #3   ---
# XBINNING  =  1   ---
# YBINNING  =  1   ---
# SHMODE  =  Rolling shutter   ---   Electronic shutter mode
# DRMODE  =  HDR   ---   Dynamic range mode
# COMODE  =  Mono 16   ---   Color mode
# RDNOISE  =  1.8   ---   [e] Readout noise
# SATLEVEL  =  65536   ---   [ADU] Saturation level
# GAIN  =  0.41   ---   [e/ADU] Gain
# DC  =  0.007   ---   [e/s] Nominal dark current
# PARITY  =  pos   ---   Image parity
# OVERSCSX  =  0   ---   Overscan region origin in X axis
# OVERSCNX  =  14300   ---   Overscan region lines in X axis
# OVERSCSY  =  10658   ---   Overscan region origin in Y axis
# OVERSCNY  =  88   ---   Overscan region lines in Y axis
# EFFECTSX  =  51   ---   Effective region origin in X axis
# EFFECTNX  =  14200   ---   Effective region lines in X axis
# EFFECTSY  =  0   ---   Effective region origin in Y axis
# EFFECTNY  =  10650   ---   Effective region lines in Y axis
# STATSX  =  6640   ---   Stats region origin in X axis
# STATNX  =  1024   ---   Stats region lines in X axis
# STATSY  =  4862   ---   Stats region origin in Y axis
# STATNY  =  1024   ---   Stats region lines in Y axis
# FOCUS  =  12370   ---   [um] Focuser position
# WINDOWSX  =  0   ---
# WINDOWNX  =  14304   ---
# WINDOWSY  =  0   ---
# WINDOWNY  =  10748   ---
# FILTER  =  SDSSr   ---
# DATE-OBS  =  2025-01-08T23:13:10.194024   ---
# JD-OBS  =  2460684.467479098   ---   Julian date
# MJD-OBS  =  60683.9674790975   ---   Modified julian date
# PCDATE  =  2025-01-08T23:13:11.332103   ---
# EXPTIME  =  398.415   ---
# INTEMP  =  -15.0   ---
# OBJECT  =  SDSSJ0819+5356   ---
# UT1  =  2025-01-08T23:13:10.194024   ---   [UTC] Datetime of sub-frame 1
# GPSDAT1  =  2025-01-08T23:13:10.194024   ---   GPS [UTC] Datetime of sub-frame 1
# GPSLAT1  =  28.2987605   ---   GPS [deg] Latitude measured by the GPS 1
# GPSLON1  =  -16.50956333333333   ---   GPS [deg] Longitude measured by the GPS 1
# PCDAT1  =  2025-01-08T23:13:11.332103   ---   PC [UTC] Datetime of sub-frame 1
# EXPT1  =  39.841483   ---   [s] Exposure time of sub-frame 1
# TEMP1  =  -15.0   ---   [C] Instrument temperature of sub-frame 1
# SEQNUM1  =  2   ---   Number in the sequenceof sub-frame 1
# UT2  =  2025-01-08T23:13:50.047706   ---   [UTC] Datetime of sub-frame 2
# GPSDAT2  =  2025-01-08T23:13:50.047706   ---   GPS [UTC] Datetime of sub-frame 2
# GPSLAT2  =  28.29876316666667   ---   GPS [deg] Latitude measured by the GPS 2
# GPSLON2  =  -16.50958166666667   ---   GPS [deg] Longitude measured by the GPS 2
# PCDAT2  =  2025-01-08T23:13:51.172212   ---   PC [UTC] Datetime of sub-frame 2
# EXPT2  =  39.841483   ---   [s] Exposure time of sub-frame 2
# TEMP2  =  -15.0   ---   [C] Instrument temperature of sub-frame 2
# SEQNUM2  =  3   ---   Number in the sequenceof sub-frame 2
# UT3  =  2025-01-08T23:14:29.901405   ---   [UTC] Datetime of sub-frame 3
# GPSDAT3  =  2025-01-08T23:14:29.901405   ---   GPS [UTC] Datetime of sub-frame 3
# GPSLAT3  =  28.2987565   ---   GPS [deg] Latitude measured by the GPS 3
# GPSLON3  =  -16.50958666666667   ---   GPS [deg] Longitude measured by the GPS 3
# PCDAT3  =  2025-01-08T23:14:30.995018   ---   PC [UTC] Datetime of sub-frame 3
# EXPT3  =  39.841483   ---   [s] Exposure time of sub-frame 3
# TEMP3  =  -15.0   ---   [C] Instrument temperature of sub-frame 3
# SEQNUM3  =  4   ---   Number in the sequenceof sub-frame 3
# UT4  =  2025-01-08T23:15:09.755105   ---   [UTC] Datetime of sub-frame 4
# GPSDAT4  =  2025-01-08T23:15:09.755105   ---   GPS [UTC] Datetime of sub-frame 4
# GPSLAT4  =  28.2987925   ---   GPS [deg] Latitude measured by the GPS 4
# GPSLON4  =  -16.50959166666667   ---   GPS [deg] Longitude measured by the GPS 4
# PCDAT4  =  2025-01-08T23:15:10.853694   ---   PC [UTC] Datetime of sub-frame 4
# EXPT4  =  39.841483   ---   [s] Exposure time of sub-frame 4
# TEMP4  =  -15.0   ---   [C] Instrument temperature of sub-frame 4
# SEQNUM4  =  5   ---   Number in the sequenceof sub-frame 4
# UT5  =  2025-01-08T23:15:49.608805   ---   [UTC] Datetime of sub-frame 5
# GPSDAT5  =  2025-01-08T23:15:49.608805   ---   GPS [UTC] Datetime of sub-frame 5
# GPSLAT5  =  28.29879066666667   ---   GPS [deg] Latitude measured by the GPS 5
# GPSLON5  =  -16.50959333333333   ---   GPS [deg] Longitude measured by the GPS 5
# PCDAT5  =  2025-01-08T23:15:50.701122   ---   PC [UTC] Datetime of sub-frame 5
# EXPT5  =  39.841483   ---   [s] Exposure time of sub-frame 5
# TEMP5  =  -15.0   ---   [C] Instrument temperature of sub-frame 5
# SEQNUM5  =  6   ---   Number in the sequenceof sub-frame 5
# UT6  =  2025-01-08T23:16:29.462505   ---   [UTC] Datetime of sub-frame 6
# GPSDAT6  =  2025-01-08T23:16:29.462505   ---   GPS [UTC] Datetime of sub-frame 6
# GPSLAT6  =  28.29879433333333   ---   GPS [deg] Latitude measured by the GPS 6
# GPSLON6  =  -16.509595   ---   GPS [deg] Longitude measured by the GPS 6
# PCDAT6  =  2025-01-08T23:16:30.552162   ---   PC [UTC] Datetime of sub-frame 6
# EXPT6  =  39.841483   ---   [s] Exposure time of sub-frame 6
# TEMP6  =  -15.0   ---   [C] Instrument temperature of sub-frame 6
# SEQNUM6  =  7   ---   Number in the sequenceof sub-frame 6
# UT7  =  2025-01-08T23:17:09.316204   ---   [UTC] Datetime of sub-frame 7
# GPSDAT7  =  2025-01-08T23:17:09.316204   ---   GPS [UTC] Datetime of sub-frame 7
# GPSLAT7  =  28.29879266666667   ---   GPS [deg] Latitude measured by the GPS 7
# GPSLON7  =  -16.50960333333333   ---   GPS [deg] Longitude measured by the GPS 7
# PCDAT7  =  2025-01-08T23:17:10.409441   ---   PC [UTC] Datetime of sub-frame 7
# EXPT7  =  39.841483   ---   [s] Exposure time of sub-frame 7
# TEMP7  =  -15.0   ---   [C] Instrument temperature of sub-frame 7
# SEQNUM7  =  8   ---   Number in the sequenceof sub-frame 7
# UT8  =  2025-01-08T23:17:49.169904   ---   [UTC] Datetime of sub-frame 8
# GPSDAT8  =  2025-01-08T23:17:49.169904   ---   GPS [UTC] Datetime of sub-frame 8
# GPSLAT8  =  28.2987825   ---   GPS [deg] Latitude measured by the GPS 8
# GPSLON8  =  -16.50960166666666   ---   GPS [deg] Longitude measured by the GPS 8
# PCDAT8  =  2025-01-08T23:17:50.262533   ---   PC [UTC] Datetime of sub-frame 8
# EXPT8  =  39.841483   ---   [s] Exposure time of sub-frame 8
# TEMP8  =  -15.0   ---   [C] Instrument temperature of sub-frame 8
# SEQNUM8  =  9   ---   Number in the sequenceof sub-frame 8
# UT9  =  2025-01-08T23:18:29.023585   ---   [UTC] Datetime of sub-frame 9
# GPSDAT9  =  2025-01-08T23:18:29.023585   ---   GPS [UTC] Datetime of sub-frame 9
# GPSLAT9  =  28.2987785   ---   GPS [deg] Latitude measured by the GPS 9
# GPSLON9  =  -16.50959833333333   ---   GPS [deg] Longitude measured by the GPS 9
# PCDAT9  =  2025-01-08T23:18:30.107441   ---   PC [UTC] Datetime of sub-frame 9
# EXPT9  =  39.841483   ---   [s] Exposure time of sub-frame 9
# TEMP9  =  -15.0   ---   [C] Instrument temperature of sub-frame 9
# SEQNUM9  =  10   ---   Number in the sequenceof sub-frame 9
# UT10  =  2025-01-08T23:19:08.877285   ---   [UTC] Datetime of sub-frame 10
# GPSDAT10  =  2025-01-08T23:19:08.877285   ---   GPS [UTC] Datetime of sub-frame 10
# GPSLAT10  =  28.2987735   ---   GPS [deg] Latitude measured by the GPS 10
# GPSLON10  =  -16.50959166666667   ---   GPS [deg] Longitude measured by the GPS 10
# PCDAT10  =  2025-01-08T23:19:09.960313   ---   PC [UTC] Datetime of sub-frame 10
# EXPT10  =  39.841483   ---   [s] Exposure time of sub-frame 10
# TEMP10  =  -15.0   ---   [C] Instrument temperature of sub-frame 10
# SEQNUM10  =  11   ---   Number in the sequenceof sub-frame 10
# UTOBS  =  2025-01-08T23:16:29.456394   ---   [UTC] Mean datetime of observation
# INTEGT  =  398.4   ---   [s] Sum of all exposition times
# TOTIMA  =  10   ---   Number of captures for this image
# ORID  =  20283   ---
# OBID  =  1850583   ---
# OBLINEID  =  2007296   ---
# BIASCORR  =  bias   ---   Bias correction method
# BIASMEAN  =  187.746   ---   [ADU] MasterBias mean
# BIASSTD  =  7.301   ---   [ADU] MasterBias standard deviation
# BIASOVER  =  184.051   ---   [ADU] Median level in MasterBias overscan
# BIASN  =  21   ---   Number of stacked frames in MasterBias
# BIASTEMP  =  -12.5   ---   [C] Instrument temperature of MasterBias
# BIASDATE  =  2024-03-05T14:31:20.614337   ---   [UTC] Date of capture of MasterBias
# FLATMEAN  =  13819.827   ---   [ADU] Mean of the MasterFlat frame
# FLATSTD  =  192.372   ---   [ADU] Standard deviation in flat stacking
# FLATN  =  11   ---   Number of staked frames in MasterFlat
# FLATTEMP  =  -13.2   ---   [C] Instrument temperature of MasterFlat
# FLATDATE  =  2025-01-02T18:38:16.526514   ---   [UTC] Date of capture of MasterFlat
# DATE  =  2025-01-08T23:21:04   ---   [UTC] Date of file creation
# HUMIDITY  =  10.007   ---   [%] Relative humidity
# MIRRHUM  =  10.163   ---   [%] Telescope mirror relative humidity
# PRESSURE  =  773.871   ---   [mbar] Local pressure
# AMBTEMP  =  6.38   ---   [C] Ambient temperature
# MIRRTEMP  =  5.68   ---   [C] Telescope mirror temperature
# WINDDIR  =  0.0   ---   [deg] Wind direction
# WINDVEL  =  0.0   ---   [m/s] Wind speed
# DUSTPM1  =  0.03   ---   [ug/m3] Particle matter density <1 micron
# DUSTPM10  =  0.03   ---   [ug/m3] Particle matter density <10 micron
# DUSTPM25  =  0.03   ---   [ug/m3] Particle matter density <2.5 micron
# DEWPOINT  =  -34.95   ---   [C] Dew point
# RA  =  125.0099906390858   ---   [deg] Central right ascension
# DEC  =  53.94133373792898   ---   [deg] Central declination
# RAHMS  =  08:20:2.397753   ---   [hh:mm:ss] Central Right ascension
# DECDMS  =  53:56:28.801457   ---   [dd:mm:ss] Central declination
# FOVX  =  33.37   ---   [arcmin] Field of view in x axis
# FOVY  =  25.03   ---   [arcmin] Field of view in y axis
# SCALE  =  0.141   ---   [arcsec/px] Calculated plate scale
# CCW  =  -179.7   ---   [deg] Field rotation counterclockwise
# AZ  =  39.075253   ---   [deg] Azimut
# ALT  =  48.61388   ---   [deg] Altitude
# ZD  =  41.38612   ---   [deg] Zenital distance, in degrees
# AIRMASS  =  1.332851   ---   Airmass
# LONGAL  =  164.336222   ---   [deg] Galactic longitude
# LATGAL  =  34.481511   ---   [deg] Galactic latitude
# LONECL  =  113.849115   ---   [deg] Baricentric mean ecliptic longitude
# LATECL  =  33.362612   ---   [deg] Baricentric mean ecliptic latitude
# MOONALT  =  52.59   ---   [deg] Moon altitude
# MOONAZ  =  265.28   ---   [deg] Moon azimut
# MOONILUM  =  71.824   ---   [%] Moon illumination
# MOONDIST  =  71.47   ---   [deg] Distance to Moon
# SUNALT  =  -62.26   ---   [deg] Sun altitude
# SUNAZ  =  276.07   ---   [deg] Sun azimut
# WCSAXES  =  2   ---   Number of coordinate axes
# EQUINOX  =  2000.0   ---   Equatorial coordinates definition (yr)
# LONPOLE  =  180.0   ---   Native longitude of celestial pole (deg)
# LATPOLE  =  0.0   ---   Native latitude of celestial pole (deg)
# CRVAL1  =  125.1963231168608   ---   RA of reference point
# CRVAL2  =  53.90935692661468   ---   DEC of reference point
# CRPIX1  =  9898.506415039583   ---   X reference pixel
# CRPIX2  =  6127.994593058058   ---   Y reference pixel
# CUNIT1  =  deg   ---   X pixel scale units
# CUNIT2  =  deg   ---   Y pixel scale units
# CD1_1  =  3.92535991743003e-05   ---   Transformation matrix
# CD1_2  =  -2.1624968559194e-07   ---   Transformation matrix
# CD2_1  =  -2.1486736461079e-07   ---   Transformation matrix
# CD2_2  =  -3.92526699444e-05   ---   Transformation matrix
# CTYPE1  =  RA---TAN-SIP   ---   TAN (gnomonic) projection + SIP distortions
# CTYPE2  =  DEC--TAN-SIP   ---   TAN (gnomonic) projection + SIP distortions
# A_ORDER  =  1   ---   Polynomial order, axis 1
# A_0_0  =  0.0   ---   Polynomial coefficient, axis 1
# A_0_1  =  0.0   ---   Polynomial coefficient, axis 1
# A_1_0  =  0.0   ---   Polynomial coefficient, axis 1
# B_ORDER  =  1   ---   Polynomial order, axis 2
# B_0_0  =  0.0   ---   Polynomial coefficient, axis 2
# B_0_1  =  0.0   ---   Polynomial coefficient, axis 2
# B_1_0  =  0.0   ---   Polynomial coefficient, axis 2
# AP_ORDER  =  1   ---   Inv polynomial order, axis 1
# AP_0_0  =  -0.0   ---   Inv polynomial coefficient, axis 1
# AP_0_1  =  0.0   ---   Inv polynomial coefficient, axis 1
# AP_1_0  =  -0.0   ---   Inv polynomial coefficient, axis 1
# BP_ORDER  =  1   ---   Inv polynomial order, axis 2
# BP_0_0  =  -0.0   ---   Inv polynomial coefficient, axis 2
# BP_0_1  =  0.0   ---   Inv polynomial coefficient, axis 2
# BP_1_0  =  -0.0   ---   Inv polynomial coefficient, axis 2
# FLUXSKY  =  40.962845   ---   [ADU/px] Median sky flux per pixel
# FWHM  =  7.41207182367794   ---   [px] FWHM in the center of the image
# FWHMLL  =  10.86   ---   [px] FWHM in the lower-left corner
# FWHMLR  =  8.54   ---   [px] FWHM in the lower-right corner
# FWHMUL  =  9.48   ---   [px] FWHM in the upper-left corner
# FWHMUR  =  7.57   ---   [px] FWHM in the upper-right corner
# RAD10  =  6   ---   [px] Aperture radius for stars with SNR = 10
# CORR10  =  0.525   ---   Aperture correction factor for SNR = 10
# RAD100  =  21   ---   [px] Aperture radius for stars with SNR = 100
# CORR100  =  0.945   ---   Aperture correction factor for SNR = 100
# RAD250  =  39   ---
# CORR250  =  0.99   ---
# RAD1000  =  53   ---   [px] Aperture radius for stars with SNR = 1000
# CORR1000  =  1.0   ---   Aperture correction factor for SNR = 1000
# CATALOG  =  II/349/ps1   ---   Photometric catalog used in calibration
# CATBAND  =  r   ---   Catalog passband
# ZP  =  23.9111   ---   [ADU/s] Zeropoint
# EZP  =  0.0027   ---   [ADU/s] Zeropoint uncertainty (1-sigma)
# CATNSTAR  =  45   ---   Number of stars used in ZP
# ZPMINMAG  =  14.54   ---   [mag] Brightest star magnitude for ZP
# ZPMAXMAG  =  18.05   ---   [mag] Faintest star magnitude for ZP
# BVMIN  =  0.35   ---   [B-V] Minimum color for ZP stars
# BVMAX  =  0.95   ---   [B-V] Maximum color for ZP stars
# RAPREC  =  -0.01   ---   [arcsec] RA precision of detected sources
# DECPREC  =  0.067   ---   [arcsec] DEC precision of detected sources
# RADISP  =  0.312   ---   [arcsec] RA dispersion of detected sources
# DECDISP  =  0.217   ---   [arcsec] DEC dispersion of detected sources
# MAGLIM  =  22.91   ---   [mag] 3-sigma limiting magnitude
# OBJECSNR  =  26.82   ---   Target signal-to-noise ratio
# DATEPROC  =  2025-01-09T13:12:42.421342   ---   [UTC] Date when the file was processed

# %% [markdown]
# # Work with historic dataframe imported from .pkl file

# %%
df = pd.read_pickle('df_files_all.pkl')
#df.set_index('date_time').groupby('object').resample('D').size().unstack(0)
df['day'] = df['date_time'].dt.date
df
# Out:
#                                                   filename  \
# 0        ATLAS-Teide-P_2023-05-01-22-01-07-273279_AL62....
# 1        ATLAS-Teide-P_2023-05-02-04-51-46-695793_AM82....
# 2        ATLAS-Teide-P_2023-05-04-00-05-04-730911_Focus...
# 3        ATLAS-Teide-P_2023-05-04-00-23-31-426872_Focus...
# 4        ATLAS-Teide-P_2023-05-04-00-32-10-828223_Focus...
# ...                                                    ...
# 1357711  TTT3_iKon936-1_2025-10-31-06-43-58-638998_TOI-...
# 1357712  TTT3_iKon936-1_2025-10-31-06-44-28-510311_TOI-...
# 1357713  TTT3_iKon936-1_2025-10-31-06-44-58-381037_TOI-...
# 1357714  TTT3_iKon936-1_2025-10-31-06-45-28-250995_TOI-...
# 1357715  TTT3_iKon936-1_2025-10-31-06-45-58-121308_TOI-...
#
#                                                       path telescope  \
# 0        /home/oscarsoler/work/red/2023-05-01/ATLAS-Tei...       err
# 1        /home/oscarsoler/work/red/2023-05-01/ATLAS-Tei...       err
# 2        /home/oscarsoler/work/red/2023-05-03/ATLAS-Tei...       err
# 3        /home/oscarsoler/work/red/2023-05-03/ATLAS-Tei...       err
# 4        /home/oscarsoler/work/red/2023-05-03/ATLAS-Tei...       err
# ...                                                    ...       ...
# 1357711  /home/oscarsoler/work/red/2025-10-30/TTT3_iKon...      TTT3
# 1357712  /home/oscarsoler/work/red/2025-10-30/TTT3_iKon...      TTT3
# 1357713  /home/oscarsoler/work/red/2025-10-30/TTT3_iKon...      TTT3
# 1357714  /home/oscarsoler/work/red/2025-10-30/TTT3_iKon...      TTT3
# 1357715  /home/oscarsoler/work/red/2025-10-30/TTT3_iKon...      TTT3
#
#             camera    object  filter    size_MB                  date_time  \
# 0              err       err          244.37664 2000-01-01 00:00:00.000000
# 1              err       err          244.37088 2000-01-01 00:00:00.000000
# 2              err       err          244.37664 2000-01-01 00:00:00.000000
# 3              err       err          244.37088 2000-01-01 00:00:00.000000
# 4              err       err          244.37088 2000-01-01 00:00:00.000000
# ...            ...       ...     ...        ...                        ...
# 1357711  iKon936-1  TOI-2267  SDSSzs   16.79040 2025-10-31 06:43:58.638998
# 1357712  iKon936-1  TOI-2267  SDSSzs   16.79040 2025-10-31 06:44:28.510311
# 1357713  iKon936-1  TOI-2267  SDSSzs   16.79040 2025-10-31 06:44:58.381037
# 1357714  iKon936-1  TOI-2267  SDSSzs   16.79040 2025-10-31 06:45:28.250995
# 1357715  iKon936-1  TOI-2267  SDSSzs   16.79040 2025-10-31 06:45:58.121308
#
#                 day
# 0        2000-01-01
# 1        2000-01-01
# 2        2000-01-01
# 3        2000-01-01
# 4        2000-01-01
# ...             ...
# 1357711  2025-10-31
# 1357712  2025-10-31
# 1357713  2025-10-31
# 1357714  2025-10-31
# 1357715  2025-10-31
#
# [1357716 rows x 9 columns]

# %%
grav_lens = ['QSO0957+561', 'Q2237+030', 'MG1654+1346', 'SDSSJ1004+4112', 'LBQS1333+0113', 'SDSSJ0819+5356',
             'EinsteinCross']

# for g in grav_lens:
#     try: print(g, df.value_counts(['object']).loc[(g)])
#     except: print()


# Filter the DataFrame
df_filtered = df[df["object"].isin(grav_lens)].copy()

# Group by day and object, count observations
daily_counts = (
    df_filtered.groupby(["day", "object"])
    .size()
    .reset_index(name="count")
    )

# daily_counts.groupby(['filter']).size()

# %% [markdown]
# ## Timeline overview of gravitational lens object observations

# %%
# Pivot for plotting
pivoted = daily_counts.pivot(index="day", columns="object", values="count").fillna(0)
pivot_for_plot = pivoted.where(pivoted != 0, np.nan)
# Remove days where all objects are NaN (no observations at all)
pivot_for_plot = pivot_for_plot.dropna(how="all")
# optional: sort index (dates) to ensure proper time order
pivot_for_plot = pivot_for_plot.sort_index()
# Plot
fig, ax = plt.subplots()

pivot_for_plot.plot(kind="line", marker="o", lw=0, alpha=0.5, figsize=(10, 5), ax=ax)


ax.set_title("Daily Observations by Object")
ax.minorticks_on()
ax.set_xlabel("Date")
ax.tick_params('x', rotation = 45)
ax.set_ylabel("Number of Observations")
ax.legend(title="Object")
ax.grid(alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x11a229690> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x11a229690> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 2 doesn't match <NSViewBackingLayer: 0x11a229690> contents scale of 1 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.
# qt.qpa.backingstore: Back buffer dpr of 1 doesn't match <NSViewBackingLayer: 0x32ffbe780> contents scale of 2 - updating layer to match.

# %%
plt.savefig('grav_lens_overview_object_date.png', dpi=200)

# %%
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)

# %% [markdown]
# ## Overview of timeline observations separated by filter for each object

# %%
# Assiging each filter a color
filters_list = df_filtered.groupby('filter').size().keys().to_list()
n_filters = len(filters_list)

colors_dict = {filters_list[i]: plt.cm.tab10.colors[i] for i in range(n_filters)}
colors_list = [plt.cm.tab10.colors[i] for i in range(n_filters)]

# Create figure
# CORRECT to adjust to total number of filters
fig, ax = plt.subplots(4, 2)

for i, obj in enumerate(grav_lens):
    # Group by date, object, filter and count observations
    summary = (
        df_filtered[df_filtered['object']==obj].groupby(['day', 'object', 'filter'])
        .size()
        .reset_index(name='n_observations')
    )
    # Pivot the grouped data: rows are dates, columns are (object, filter) multiindex, values are counts
    pivoted = summary.pivot_table(
                                index='day',
                                columns=['object', 'filter'],
                                values='n_observations',
                                fill_value=0
)
# Plot as stacked bar chart
    #piv_plot = pivoted[pivoted['object']==obj].copy()
    iax = i//2
    jax = i%2
    # extract filters used for the object
    filters_object = summary.groupby('filter').size().keys().to_list()
    colors_object = [colors_dict.get(f, '#333333') for f in filters_object]
    pivoted.plot(
        kind='bar',
        stacked=True,
        figsize=(15, 7),
        ax=ax[iax, jax],
        legend = False,
        color = colors_object
    )
    ax[iax, jax].locator_params(axis='x', nbins=5)
    ax[iax, jax].tick_params('x', rotation = 0)
    ax[iax, jax].set_xlabel('')
    ax[iax, jax].set_title(obj)

    if iax == ax.shape[0]-1:
        ax[iax, jax].set_xlabel('Observation Date')
    if jax==0:
       ax[iax, jax].set_ylabel('Number of\nObservations')
    else:
        ax[iax, jax].set_ylabel('')

fig.suptitle('Daily Number of Observations per Object and Filter')
# Custom legend handles
ax[-1,-1].set_axis_off()
handles = [patches.Patch(color = colors_list[i], label =filters_list[i]) for i in range(n_filters)]
ax[-1,-1].legend(title='Filter', #bbox_to_anchor=(1.05, 1), loc='lower center',
           handles = handles, ncols = n_filters)
plt.tight_layout()
plt.show()

# %%
plt.savefig('grav_lens_overview_object_date_filter.png', dpi=200)

# %%
filters_list
# Out:
# ['SDSSg', 'SDSSi', 'SDSSr', 'SDSSu', 'SDSSy', 'SDSSzs']

# %%
df_filtered.groupby(['object', 'filter', 'telescope']).size()
# Out:
# object          filter  telescope
# EinsteinCross   SDSSg   TTT3           28
#                 SDSSr   TTT3           28
# LBQS1333+0113   SDSSg   TTT1           65
#                         TTT2           90
#                 SDSSi   TTT1           65
#                         TTT2           90
#                 SDSSr   TTT1           65
#                         TTT2           90
# MG1654+1346     SDSSg   TTT1          158
#                         TTT2          469
#                         TTT3          322
#                 SDSSi   TTT1          159
#                         TTT2          468
#                         TTT3          322
#                 SDSSr   TTT1          158
#                         TTT2          468
#                         TTT3          322
# Q2237+030       SDSSg   TTT3           77
#                 SDSSi   TTT3           77
#                 SDSSr   TTT3           77
#                 SDSSzs  TTT3           77
# QSO0957+561     SDSSg   TST          1388
#                         TTT1         1744
#                         TTT2          902
#                         TTT3         1544
#                 SDSSi   TST          1385
#                         TTT1         1745
#                         TTT2          901
#                         TTT3         1530
#                 SDSSr   TST          1387
#                         TTT1         1746
#                         TTT2          898
#                         TTT3         1786
#                 SDSSu   TTT1           56
#                         TTT3           53
#                 SDSSy   TTT3           46
#                 SDSSzs  TTT1           48
#                         TTT3          455
# SDSSJ0819+5356  SDSSg   TTT1           88
#                         TTT2           61
#                 SDSSi   TTT1           85
#                         TTT2           57
#                 SDSSr   TTT1           88
#                         TTT2           60
#                 SDSSu   TTT1            8
#                 SDSSzs  TTT1            9
# SDSSJ1004+4112  SDSSg   TTT1           42
#                         TTT2           28
#                 SDSSi   TTT1           41
#                         TTT2           28
#                 SDSSr   TTT1           43
#                         TTT2           28
# dtype: int64

# %% [markdown]
# # Future work

# %%
# ------- FUTURE WORK: IMAGE DATA HISTOGRAM ---------
# data = iv.read_data(1)
print(np.mean(data))
print(np.median(data))
print(np.std(data))
print(np.max(data),'-', np.min(data))
plt.hist(data.ravel(), bins=100)
plt.yscale('log')
plt.xscale('log')
plt.show()
